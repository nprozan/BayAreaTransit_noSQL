# %% [markdown]
# # Project 3 - Code for neo4j business case for AGM
#
# University of California, Berkeley
#
# Master of Information and Data Science (MIDS) program
#
# w205 - Fundamentals of Data Engineering

# %% [markdown]
# # Business Case for Neo4j - Proposed Solution
#
# * Build a graph database in Neo4j for the BART system
# * Use the Louvain Modularity Algorithm to identify strong knit communities of stations (11 communities identified)
# * From each community, pick one station that has the potential to reach the maximum customer base (Using geodesic population grids)
# * Use the selected 11 stations as pilot delivery points for phase I

# %% [markdown]
# # Included modules

# %%
import neo4j

import csv

import math
import numpy as np
import pandas as pd

import psycopg2

from geographiclib.geodesic import Geodesic

pd.set_option('display.max_rows', 1000)

# %% [markdown]
# # Supporting code
#
# Code reused from the labs and project 3 exercise

# %%
driver = neo4j.GraphDatabase.driver(uri="neo4j://neo4j:7687", auth=("neo4j","w205"))

# %%
session = driver.session(database="neo4j")

# %%
def my_neo4j_run_query_pandas(query, **kwargs):
    "run a query and return the results in a pandas dataframe"
    
    result = session.run(query, **kwargs)
    
    df = pd.DataFrame([r.values() for r in result], columns=result.keys())
    
    return df

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)

cursor = connection.cursor()

# %%
def my_calculate_box(point, miles):
    "Given a point and miles, calculate the box in form left, right, top, bottom"
    
    geod = Geodesic.WGS84

    kilometers = miles * 1.60934
    meters = kilometers * 1000

    g = geod.Direct(point[0], point[1], 270, meters)
    left = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 90, meters)
    right = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 0, meters)
    top = (g['lat2'], g['lon2'])

    g = geod.Direct(point[0], point[1], 180, meters)
    bottom = (g['lat2'], g['lon2'])
    
    return(left, right, top, bottom)

# %%
def my_station_get_zips(station, miles):
    "given a station, pull all zip codes with miles distance, print them, sum the population"
    
    connection.rollback()
    
    query = "select latitude, longitude from stations "
    query += "where station = '" + station + "'"
    
    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    for row in rows:
        latitude = row[0]
        longitude = row[1]
        
    point = (latitude, longitude)
        
    (left, right, top, bottom) = my_calculate_box(point, miles)
    
    query = "select zip, population from zip_codes "
    query += " where latitude >= " + str(bottom[0])
    query += " and latitude <= " + str(top [0])
    query += " and longitude >= " + str(left[1])
    query += " and longitude <= " + str(right[1])
    query += " order by 1 "

    cursor.execute(query)
    
    connection.rollback()
    
    rows = cursor.fetchall()
    
    #print("\n-------------------------------------------------------------------------------")
    #print("  Zip Codes within " + str(miles) + " mile(s) of " + station + " BART Station")
    #print("-------------------------------------------------------------------------------\n")
    
    total_population = 0
    
    for row in rows:
        zip = row[0]
        population = row[1]
        #print("     zip:", zip, "  population: ", f'{population:10,}')
        total_population += population
        
    
    #print("\n-------------------------------------------------------------------------------")
    #print("  Total Population: ", f'{total_population:10,}')
    #print("-------------------------------------------------------------------------------")
    #
    return total_population

# %%
# if it will fit in an integer, change it to integer
#

def my_select_query_pandas(query, rollback_before_flag, rollback_after_flag):
    "function to run a select query and return rows in a pandas dataframe"
    
    if rollback_before_flag:
        connection.rollback()
    
    df = pd.read_sql_query(query, connection)
    
    if rollback_after_flag:
        connection.rollback()
    
    # fix the float columns that really should be integers
    
    for column in df:
    
        if df[column].dtype == "float64":

            fraction_flag = False

            for value in df[column].values:
                
                if not np.isnan(value):
                    if value - math.floor(value) != 0:
                        fraction_flag = True

            if not fraction_flag:
                df[column] = df[column].astype('Int64')
    
    return(df)

# %% [markdown]
# # Louvain Modularity
# We use the Louvaine Modularity community detction algorithm to group stations into communities. The premise is that if there are mutiple sttaions in a close knit community we whave good chances of reaching out to the population served by all these sttaions by just having a delivery point at one of the staaions. This helps us optimize our delivery infrastructure while maximizing return on investment.

# %%
# Run the Louvain Modularity algorithm on the graph created in the exercise 
query = "CALL gds.graph.drop('ds_graph', false)"
session.run(query)

query = "CALL gds.graph.create('ds_graph', 'Station', 'LINK', {relationshipProperties: 'weight'})"
session.run(query)
query = """

CALL gds.louvain.stream('ds_graph')
YIELD nodeId, communityId, intermediateCommunityIds
RETURN gds.util.asNode(nodeId).name AS name, communityId as community, intermediateCommunityIds as intermediate_community
ORDER BY community, name ASC

"""

communities_df = my_neo4j_run_query_pandas(query)

print(communities_df)
# Out:
#                             name  community intermediate_community
# 0     arrive 16th Street Mission          7                   None
# 1     arrive 24th Street Mission          7                   None
# 2       blue 16th Street Mission          7                   None
# 3       blue 24th Street Mission          7                   None
# 4     depart 16th Street Mission          7                   None
# 5     depart 24th Street Mission          7                   None
# 6      green 16th Street Mission          7                   None
# 7      green 24th Street Mission          7                   None
# 8        red 16th Street Mission          7                   None
# 9        red 24th Street Mission          7                   None
# 10    yellow 16th Street Mission          7                   None
# 11    yellow 24th Street Mission          7                   None
# 12           arrive Civic Center         21                   None
# 13          arrive Powell Street         21                   None
# 14             blue Civic Center         21                   None
# 15            blue Powell Street         21                   None
# 16           depart Civic Center         21                   None
# 17          depart Powell Street         21                   None
# 18            green Civic Center         21                   None
# 19           green Powell Street         21                   None
# 20              red Civic Center         21                   None
# 21             red Powell Street         21                   None
# 22           yellow Civic Center         21                   None
# 23          yellow Powell Street         21                   None
# 24            arrive Balboa Park         29                   None
# 25              arrive Daly City         29                   None
# 26              arrive Glen Park         29                   None
# 27              blue Balboa Park         29                   None
# 28                blue Daly City         29                   None
# 29                blue Glen Park         29                   None
# 30            depart Balboa Park         29                   None
# 31              depart Daly City         29                   None
# 32              depart Glen Park         29                   None
# 33             green Balboa Park         29                   None
# 34               green Daly City         29                   None
# 35               green Glen Park         29                   None
# 36               red Balboa Park         29                   None
# 37                 red Daly City         29                   None
# 38                 red Glen Park         29                   None
# 39            yellow Balboa Park         29                   None
# 40              yellow Daly City         29                   None
# 41              yellow Glen Park         29                   None
# 42                  arrive Ashby         31                   None
# 43      arrive Downtown Berkeley         31                   None
# 44       arrive El Cerrito Plaza         31                   None
# 45   arrive El Cerrito del Norte         31                   None
# 46         arrive North Berkeley         31                   None
# 47               arrive Richmond         31                   None
# 48                  depart Ashby         31                   None
# 49      depart Downtown Berkeley         31                   None
# 50       depart El Cerrito Plaza         31                   None
# 51   depart El Cerrito del Norte         31                   None
# 52         depart North Berkeley         31                   None
# 53               depart Richmond         31                   None
# 54                  orange Ashby         31                   None
# 55      orange Downtown Berkeley         31                   None
# 56       orange El Cerrito Plaza         31                   None
# 57   orange El Cerrito del Norte         31                   None
# 148             depart Rockridge         63                   None
# 149          depart Walnut Creek         63                   None
# 150               yellow Antioch         63                   None
# 151               yellow Concord         63                   None
# 152             yellow Lafayette         63                   None
# 153         yellow North Concord         63                   None
# 154                yellow Orinda         63                   None
# 155             yellow Pittsburg         63                   None
# 156      yellow Pittsburg Center         63                   None
# 157         yellow Pleasant Hill         63                   None
# 158             yellow Rockridge         63                   None
# 159          yellow Walnut Creek         63                   None
# 160           arrive 12th Street         67                   None
# 161           arrive 19th Street         67                   None
# 162             arrive MacArthur         67                   None
# 163           depart 12th Street         67                   None
# 164           depart 19th Street         67                   None
# 165             depart MacArthur         67                   None
# 166           orange 12th Street         67                   None
# 167           orange 19th Street         67                   None
# 168             orange MacArthur         67                   None
# 169              red 12th Street         67                   None
# 170              red 19th Street         67                   None
# 171                red MacArthur         67                   None
# 172           yellow 12th Street         67                   None
# 173           yellow 19th Street         67                   None
# 174             yellow MacArthur         67                   None
# 175                 arrive Colma         85                   None
# 176              arrive Millbrae         85                   None
# 177                   arrive SFO         85                   None
# 178             arrive San Bruno         85                   None
# 179   arrive South San Francisco         85                   None
# 180                 depart Colma         85                   None
# 181              depart Millbrae         85                   None
# 182                   depart SFO         85                   None
# 183             depart San Bruno         85                   None
# 184   depart South San Francisco         85                   None
# 185                    red Colma         85                   None
# 186                 red Millbrae         85                   None
# 187                      red SFO         85                   None
# 188                red San Bruno         85                   None
# 189      red South San Francisco         85                   None
# 190                 yellow Colma         85                   None
# 191                   yellow SFO         85                   None
# 192             yellow San Bruno         85                   None
# 193   yellow South San Francisco         85                   None
# 194             arrive Berryessa         91                   None
# 195               arrive Fremont         91                   None
# 196              arrive Milpitas         91                   None
# 197            arrive Union City         91                   None
# 198          arrive Warm Springs         91                   None
# 199             depart Berryessa         91                   None
# 200               depart Fremont         91                   None
# 201              depart Milpitas         91                   None
# 202            depart Union City         91                   None
# 203          depart Warm Springs         91                   None
# 204              green Berryessa         91                   None
# 205                green Fremont         91                   None
# 206               green Milpitas         91                   None
# 207             green Union City         91                   None
# 208           green Warm Springs         91                   None
# 209             orange Berryessa         91                   None
# 210               orange Fremont         91                   None
# 211              orange Milpitas         91                   None
# 212            orange Union City         91                   None
# 213          orange Warm Springs         91                   None

# %% [markdown]
# # Data Clean up
# The Louvain algorithm has identified 11 communities. We need to clean this data as each station has multiple nodes assoacited with it for arrival and departure. We need to extract just the station names and corresponding community number.

# %%
communities_df['Station'] = communities_df['name'].str.split().str[1:].str.join(' ')
#Drop the duplicate station names
communities_df.drop_duplicates('Station', inplace=True)
#Now that the sttaion names have bene extracted from the original node names, remove the unrequired columns
communities_df.drop(columns=['name', 'intermediate_community'], inplace=True)
print(communities_df)
# Out:
#      community               Station
# 0            7   16th Street Mission
# 1            7   24th Street Mission
# 12          21          Civic Center
# 13          21         Powell Street
# 24          29           Balboa Park
# 25          29             Daly City
# 26          29             Glen Park
# 42          31                 Ashby
# 43          31     Downtown Berkeley
# 44          31      El Cerrito Plaza
# 45          31  El Cerrito del Norte
# 46          31        North Berkeley
# 47          31              Richmond
# 66          47              Bay Fair
# 67          47         Castro Valley
# 68          47                Dublin
# 69          47               Hayward
# 70          47           San Leandro
# 71          47         South Hayward
# 72          47           West Dublin
# 93          51              Coliseum
# 94          51             Fruitvale
# 95          51          Lake Merritt
# 96          51                   OAK
# 112         59           Embarcadero
# 113         59     Montgomery Street
# 114         59          West Oakland
# 130         63               Antioch
# 131         63               Concord
# 132         63             Lafayette
# 133         63         North Concord
# 134         63                Orinda
# 135         63             Pittsburg
# 136         63      Pittsburg Center
# 137         63         Pleasant Hill
# 138         63             Rockridge
# 139         63          Walnut Creek
# 160         67           12th Street
# 161         67           19th Street
# 162         67             MacArthur
# 175         85                 Colma
# 176         85              Millbrae
# 177         85                   SFO
# 178         85             San Bruno
# 179         85   South San Francisco
# 194         91             Berryessa
# 195         91               Fremont
# 196         91              Milpitas
# 197         91            Union City
# 198         91          Warm Springs

# %% [markdown]
# # Population
# Get the puplutaon for each stattion and add it to the dataframe

# %%
communities_df['Population'] = communities_df.apply(lambda x: my_station_get_zips(x['Station'], 5), axis=1)
communities_df.rename(columns={'community': 'Community'}, inplace=True)
print(communities_df)
# Out:
#      Community               Station Population
# 0            7   16th Street Mission     870044
# 1            7   24th Street Mission     989138
# 12          21          Civic Center     870044
# 13          21         Powell Street     870044
# 24          29           Balboa Park     936912
# 25          29             Daly City     805122
# 26          29             Glen Park     986074
# 42          31                 Ashby     487206
# 43          31     Downtown Berkeley     448042
# 44          31      El Cerrito Plaza     355903
# 45          31  El Cerrito del Norte     369372
# 46          31        North Berkeley     445973
# 47          31              Richmond     301909
# 66          47              Bay Fair     457901
# 67          47         Castro Valley     403433
# 68          47                Dublin     213807
# 69          47               Hayward     467447
# 70          47           San Leandro     494839
# 71          47         South Hayward     411490
# 72          47           West Dublin     229219
# 93          51              Coliseum     495903
# 94          51             Fruitvale     544423
# 95          51          Lake Merritt     542120
# 96          51                   OAK     410051
# 112         59           Embarcadero     698612
# 113         59     Montgomery Street     826249
# 114         59          West Oakland     473317
# 130         63               Antioch     152632
# 131         63               Concord     188050
# 132         63             Lafayette     202640
# 133         63         North Concord     165316
# 134         63                Orinda     262181
# 135         63             Pittsburg     187733
# 136         63      Pittsburg Center     206117
# 137         63         Pleasant Hill     290825
# 138         63             Rockridge     536232
# 139         63          Walnut Creek     215621
# 160         67           12th Street     510498
# 161         67           19th Street     576172
# 162         67             MacArthur     524629
# 175         85                 Colma     597747
# 176         85              Millbrae     281774
# 177         85                   SFO     320354
# 178         85             San Bruno     334455
# 179         85   South San Francisco     507636
# 194         91             Berryessa     559010
# 195         91               Fremont     315645
# 196         91              Milpitas     435506
# 197         91            Union City     326572
# 198         91          Warm Springs     321651

# %% [markdown]
# # Stations with max population within each community

# %%
idx = communities_df.groupby(['Community'])['Population'].transform(max) == communities_df['Population']
communities_df[idx].drop_duplicates('Community')
# Out:
#      community              Station Population
# 1            7  24th Street Mission     989138
# 12          21         Civic Center     870044
# 26          29            Glen Park     986074
# 42          31                Ashby     487206
# 70          47          San Leandro     494839
# 94          51            Fruitvale     544423
# 113         59    Montgomery Street     826249
# 138         63            Rockridge     536232
# 161         67          19th Street     576172
# 175         85                Colma     597747
# 194         91            Berryessa     559010
